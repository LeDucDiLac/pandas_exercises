# %% [markdown]
# <a href="https://colab.research.google.com/github/LeDucDiLac/pandas_exercises/blob/master/10_Deleting/Wine/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
wine = pd.read_csv(url)

wine.shape
# Out:
# (177, 14)

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine = wine.drop(columns = wine.columns[[0,3,6,8,10,12,13]])

wine.shape
# Out:
# (177, 7)

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins','hue']
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
wine.iloc[:3,:] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 3    13.24        2.59               21.0      118.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[3:4,'magnesium'] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine = wine.fillna({'alcohol':10,'magnesium':100})
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    10.00         NaN                NaN      100.0         NaN
# 1    10.00         NaN                NaN      100.0         NaN
# 2    10.00         NaN                NaN      100.0         NaN
# 3    13.24        2.59               21.0      100.0        2.69
# 4    14.20        1.76               15.2      100.0        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           3
# alcalinity_of_ash    3
# magnesium            0
# flavanoids           3
# proanthocyanins      3
# hue                  3
# dtype: int64

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
import random
arr = np.array([random.randrange(10) for i in range(10)])
arr
# Out:
# array([3, 9, 8, 6, 8, 4, 3, 1, 1, 4])

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.iloc[arr,:] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0     10.0         NaN                NaN      100.0         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2     10.0         NaN                NaN      100.0         NaN
# 3      NaN         NaN                NaN        NaN         NaN
# 4      NaN         NaN                NaN        NaN         NaN
#
#    proanthocyanins  hue
# 0              NaN  NaN
# 1              NaN  NaN
# 2              NaN  NaN
# 3              NaN  NaN
# 4              NaN  NaN

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isnull().sum()
# Out:
# alcohol              6
# malic_acid           8
# alcalinity_of_ash    8
# magnesium            6
# flavanoids           8
# proanthocyanins      8
# hue                  8
# dtype: int64

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine = wine.dropna(axis = 0)
wine.isnull().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine.alcohol[wine.alcohol != np.nan]
# Out:
# 5      14.39
# 7      14.83
# 10     14.12
# 11     13.75
# 12     14.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 169, dtype: float64

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine.reset_index(drop = True)
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      14.39        1.87               14.6       96.0        2.52
# 1      14.83        1.64               14.0       97.0        2.98
# 2      14.12        1.48               16.8       95.0        2.43
# 3      13.75        1.73               16.0       89.0        2.76
# 4      14.75        1.73               11.4       91.0        3.69
# ..       ...         ...                ...        ...         ...
# 164    13.71        5.65               20.5       95.0        0.61
# 165    13.40        3.91               23.0      102.0        0.75
# 166    13.27        4.28               20.0      120.0        0.69
# 167    13.17        2.59               20.0      120.0        0.68
# 168    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.98  1.02
# 1               1.98  1.08
# 2               1.57  1.17
# 3               1.81  1.15
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
